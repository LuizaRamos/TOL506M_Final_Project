# %% [markdown]
# <a href="https://colab.research.google.com/github/LuizaRamos/TOL506M_Final_Project/blob/main/notebooks/03_task3_zeroshot_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf /content/TOL506M_Final_Project

# %%
import os, sys, subprocess

REPO_URL = "https://github.com/LuizaRamos/TOL506M_Final_Project.git"
REPO_DIR = "/content/TOL506M_Final_Project"

# Always clone fresh in Colab
subprocess.run(["git", "clone", REPO_URL, REPO_DIR], check=True)

os.chdir(REPO_DIR)

if REPO_DIR not in sys.path:
    sys.path.insert(0, REPO_DIR)
os.environ["PYTHONPATH"] = REPO_DIR + os.pathsep + os.environ.get("PYTHONPATH", "")

# %%
import sys
import os
import subprocess
import importlib
import json
import time
import random
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from pathlib import Path
from collections import Counter
from PIL import Image
from typing import Dict, List, Tuple

import torch
import torch.nn as nn
from torch.utils.data import Subset, DataLoader
from torchvision import datasets, transforms
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau, CosineAnnealingLR

project_root = Path.cwd()
if project_root.name != "TOL506M_Final_Project":
    original = project_root
    while project_root.name != "TOL506M_Final_Project" and project_root != project_root.parent:
        project_root = project_root.parent

    if project_root.name == "TOL506M_Final_Project":
        os.chdir(project_root)
        print(f"Changed working directory from {original} to {project_root}")
    else:
        raise RuntimeError(
            "Could not locate the TOL506M_Final_Project root directory. "
            "Please run this notebook/script from within the project tree."
        )
else:
    print(f"Working directory: {project_root}")

if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# Plot styling
sns.set_style("whitegrid")
plt.rcParams.update({"figure.figsize": (12, 6), "font.size": 12})

print(f"\nPyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
# Out:
# Working directory: /content/TOL506M_Final_Project
#
# PyTorch version: 2.9.0+cu126
# CUDA available: True

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("alessiocorrado99/animals10")

print(f'Dataset downloaded: {path}\n')
# Out:
# Using Colab cache for faster access to the 'animals10' dataset.
# Dataset downloaded: /kaggle/input/animals10

# %%
# Import project modules
from config import Config
from data.dataset import (WildlifeDataset, SplitIndices, stratified_split,
                          compute_class_counts, materialize_split, is_italian,
                          translate_names, get_class_names, get_data_loaders)
from data.augmentation import get_train_transforms, get_val_transforms
from models.resnet_scratch import ResNet18Scratch
from tasks.task3 import zero_shot_classification
from utils.training import train_epoch, validate, EarlyStopping
from utils.evaluation import evaluate_model, get_confusion_matrix, compute_metrics
from utils.visualization import plot_training_curves, plot_confusion_matrix

Config.NUM_WORKERS = 0 # avoid multiprocessing issues in Colab

data_fractions = Config.DATA_FRACTIONS
train_size = Config.TRAIN_SPLIT
val_size = Config.VAL_SPLIT
test_size = Config.TEST_SPLIT
Config.RANDOM_SEED = 42
random_seed = Config.RANDOM_SEED

data_path = Path(path) / 'raw-img'
Config.DATA_PATH = data_path

basic_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# Download and split dataset as previously done on previous notebooks
full_dataset = datasets.ImageFolder(root=str(data_path), transform=basic_transform)
dataset_transformed = translate_names(full_dataset)

wildlife = WildlifeDataset(str(data_path), transform=basic_transform)
train_idx_base, val_idx_fixed, test_idx_fixed = stratified_split(
    full_dataset,
    train_size=train_size,
    val_size=val_size,
    test_size=test_size,
    random_seed=random_seed
)

fixed = SplitIndices(train=train_idx_base, val=val_idx_fixed, test=test_idx_fixed)

print(f'Total images: {len(wildlife)}')
print(f'Base Train images: {len(train_idx_base)}')
print(f'Validation images: {len(val_idx_fixed)}')
print(f'Test images: {len(test_idx_fixed)}')
# Out:
# Total images: 26179
# Base Train images: 18325
# Validation images: 3927
# Test images: 3927

# %%
# Create output dirs if they don't exist
Config.MODELS_DIR.mkdir(parents=True, exist_ok=True)
Config.PLOTS_DIR.mkdir(parents=True, exist_ok=True)
Config.METRICS_DIR.mkdir(parents=True, exist_ok=True)

# %%
# Task 3: Zero Shot Classification
test_dataset_zero_shot = Subset(full_dataset, test_idx_fixed)

zero_shot_test_loader = DataLoader(
    test_dataset_zero_shot,
    batch_size=Config.BATCH_SIZE,
    shuffle=False,
    num_workers=0,
)

# Make sure we are in pure zero-shot mode
Config.SIGLIP_LINEAR_PROBE = False

zero_shot_results = zero_shot_classification(
    config=Config(),
    fixed_indices=fixed,              # optional, for consistency with other tasks
    test_loader=zero_shot_test_loader,
    train_linear_probe=False          # explicitly say: no linear probe
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/253 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.50G [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/394 [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/34.4M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# Model Loaded: google/siglip2-base-patch16-224
# Classes: ['dog', 'horse', 'elephant', 'butterfly', 'chicken', 'cat', 'cow', 'sheep', 'spider', 'squirrel']
# Using prompts per class:
#   dog: ['a photo of a dog', 'a photo of a pet dog', 'a photo of a dog running outdoors', 'a close-up photo of a dog']
#   horse: ['a photo of a horse', 'a photo of a horse running in a field', 'a photo of a horse on a farm', "a close-up photo of a horse's head"]
#   elephant: ['a photo of an elephant', 'a photo of an elephant in the wild', 'a photo of an elephant in a savanna', 'a close-up photo of an elephant']
#   butterfly: ['a close-up photo of a butterfly', 'a photo of a butterfly on a flower', 'a photo of a colorful butterfly in nature', 'a macro photograph of a butterfly']
#   chicken: ['a photo of a chicken', 'a photo of a chicken on a farm', 'a photo of a hen or rooster', 'a close-up photo of a chicken']
#   cat: ['a photo of a cat', 'a photo of a pet cat indoors', 'a photo of a cat lying on a couch', "a close-up photo of a cat's face"]
#   cow: ['a photo of a cow', 'a photo of a cow on a farm', 'a photo of a cow grazing in a field', 'a close-up photo of a cow']
#   sheep: ['a photo of a sheep', 'a photo of sheep grazing in a field', 'a photo of a flock of sheep', 'a close-up photo of a sheep on a farm']
#   spider: ['a close-up photo of a spider', 'a photo of a spider on a web', 'a photo of a spider in nature', 'a macro photograph of a spider']
#   squirrel: ['a photo of a squirrel', 'a photo of a squirrel on a tree', 'a photo of a squirrel eating a nut', 'a close-up photo of a squirrel in a park']
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:2779: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(
# Zero-shot evaluating:   0%|          | 0/62 [00:00<?, ?it/s]
# Zero-Shot Test Results (SigLIP2):
#   Accuracy:  18.28%
#   Precision: 9.88%
#   Recall:    18.28%
#   F1-Score:  8.23%
#
# Zero-Shot Confusion Matrix (rows = true, cols = pred):
# [[  0 349   0   0   0  84   0 255   0  42]
#  [  0 361   0   0   0   1   0  31   0   0]
#  [  0 121   3   0   0  15   0  47   0  31]
#  [  0 107   0   0   0 172   0   1   0  37]
#  [  0 345   1   0   0  13   0  89   0  17]
#  [  0 106   0   0   0 105   0  39   0   0]
#  [  0 171   0   0   0  37   0  38   0  34]
#  [  0  38   0   0   0  13   0 209   0  13]
#  [  0 631   0   0   0  69   0   2   0  21]
#  [  0  73   0   0   0  29   0 137   0  40]]

# %%
train_dataset_zero_shot = Subset(full_dataset, train_idx_base)
val_dataset_zero_shot = Subset(full_dataset, val_idx_fixed)
test_dataset_zero_shot = Subset(full_dataset, test_idx_fixed)  # same as above

linear_train_loader = DataLoader(
    train_dataset_zero_shot,
    batch_size=Config.BATCH_SIZE,
    shuffle=True,
    num_workers=Config.NUM_WORKERS,
)

linear_val_loader = DataLoader(
    val_dataset_zero_shot,
    batch_size=Config.BATCH_SIZE,
    shuffle=False,
    num_workers=Config.NUM_WORKERS,
)

linear_test_loader = DataLoader(
    test_dataset_zero_shot,
    batch_size=Config.BATCH_SIZE,
    shuffle=False,
    num_workers=Config.NUM_WORKERS,
)

# Enable linear probe mode
Config.SIGLIP_LINEAR_PROBE = True

linear_probe_results = zero_shot_classification(
    config=Config(),
    fixed_indices=fixed,                   # same splits as Tasks 1 & 2
    train_loader=linear_train_loader,
    val_loader=linear_val_loader,
    test_loader=linear_test_loader,
    train_linear_probe=True               # turn on linear probe
)
# Out:
# Model Loaded: google/siglip2-base-patch16-224
# Classes: ['dog', 'horse', 'elephant', 'butterfly', 'chicken', 'cat', 'cow', 'sheep', 'spider', 'squirrel']
# Using prompts per class:
#   dog: ['a photo of a dog', 'a photo of a pet dog', 'a photo of a dog running outdoors', 'a close-up photo of a dog']
#   horse: ['a photo of a horse', 'a photo of a horse running in a field', 'a photo of a horse on a farm', "a close-up photo of a horse's head"]
#   elephant: ['a photo of an elephant', 'a photo of an elephant in the wild', 'a photo of an elephant in a savanna', 'a close-up photo of an elephant']
#   butterfly: ['a close-up photo of a butterfly', 'a photo of a butterfly on a flower', 'a photo of a colorful butterfly in nature', 'a macro photograph of a butterfly']
#   chicken: ['a photo of a chicken', 'a photo of a chicken on a farm', 'a photo of a hen or rooster', 'a close-up photo of a chicken']
#   cat: ['a photo of a cat', 'a photo of a pet cat indoors', 'a photo of a cat lying on a couch', "a close-up photo of a cat's face"]
#   cow: ['a photo of a cow', 'a photo of a cow on a farm', 'a photo of a cow grazing in a field', 'a close-up photo of a cow']
#   sheep: ['a photo of a sheep', 'a photo of sheep grazing in a field', 'a photo of a flock of sheep', 'a close-up photo of a sheep on a farm']
#   spider: ['a close-up photo of a spider', 'a photo of a spider on a web', 'a photo of a spider in nature', 'a macro photograph of a spider']
#   squirrel: ['a photo of a squirrel', 'a photo of a squirrel on a tree', 'a photo of a squirrel eating a nut', 'a close-up photo of a squirrel in a park']
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:2779: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(
# Zero-shot evaluating:   0%|          | 0/62 [00:00<?, ?it/s]
# Zero-Shot Test Results (SigLIP2):
#   Accuracy:  18.28%
#   Precision: 9.88%
#   Recall:    18.28%
#   F1-Score:  8.23%
#
# Zero-Shot Confusion Matrix (rows = true, cols = pred):
# [[  0 349   0   0   0  84   0 255   0  42]
#  [  0 361   0   0   0   1   0  31   0   0]
#  [  0 121   3   0   0  15   0  47   0  31]
#  [  0 107   0   0   0 172   0   1   0  37]
#  [  0 345   1   0   0  13   0  89   0  17]
#  [  0 106   0   0   0 105   0  39   0   0]
#  [  0 171   0   0   0  37   0  38   0  34]
#  [  0  38   0   0   0  13   0 209   0  13]
#  [  0 631   0   0   0  69   0   2   0  21]
#  [  0  73   0   0   0  29   0 137   0  40]]
#
# Training linear probe (logistic regression) on SigLIP2 image embeddings...
# Extracting features:   0%|          | 0/287 [00:00<?, ?it/s]
# Extracting features:   0%|          | 0/62 [00:00<?, ?it/s]
# Extracting features:   0%|          | 0/62 [00:00<?, ?it/s]
# [Linear probe] Epoch 1/50 - Train Loss: 1.4751, Train Acc: 81.70% - Val Loss: 0.8853, Val Acc: 97.58%
# [Linear probe] Epoch 2/50 - Train Loss: 0.6015, Train Acc: 98.95% - Val Loss: 0.3993, Val Acc: 99.29%
# [Linear probe] Epoch 3/50 - Train Loss: 0.3038, Train Acc: 99.31% - Val Loss: 0.2312, Val Acc: 99.29%
# [Linear probe] Epoch 4/50 - Train Loss: 0.1922, Train Acc: 99.32% - Val Loss: 0.1602, Val Acc: 99.31%
# [Linear probe] Epoch 5/50 - Train Loss: 0.1408, Train Acc: 99.32% - Val Loss: 0.1243, Val Acc: 99.34%
# [Linear probe] Epoch 6/50 - Train Loss: 0.1133, Train Acc: 99.35% - Val Loss: 0.1040, Val Acc: 99.31%
# [Linear probe] Epoch 7/50 - Train Loss: 0.0971, Train Acc: 99.35% - Val Loss: 0.0916, Val Acc: 99.31%
# [Linear probe] Epoch 8/50 - Train Loss: 0.0868, Train Acc: 99.35% - Val Loss: 0.0836, Val Acc: 99.31%
# [Linear probe] Epoch 9/50 - Train Loss: 0.0802, Train Acc: 99.35% - Val Loss: 0.0784, Val Acc: 99.34%
# [Linear probe] Epoch 10/50 - Train Loss: 0.0758, Train Acc: 99.36% - Val Loss: 0.0749, Val Acc: 99.31%
# [Linear probe] Epoch 11/50 - Train Loss: 0.0728, Train Acc: 99.37% - Val Loss: 0.0725, Val Acc: 99.31%
# [Linear probe] Epoch 12/50 - Train Loss: 0.0706, Train Acc: 99.37% - Val Loss: 0.0708, Val Acc: 99.34%
# [Linear probe] Epoch 13/50 - Train Loss: 0.0692, Train Acc: 99.38% - Val Loss: 0.0695, Val Acc: 99.39%
# [Linear probe] Epoch 14/50 - Train Loss: 0.0680, Train Acc: 99.38% - Val Loss: 0.0687, Val Acc: 99.39%
# [Linear probe] Epoch 15/50 - Train Loss: 0.0672, Train Acc: 99.39% - Val Loss: 0.0679, Val Acc: 99.39%
# [Linear probe] Epoch 16/50 - Train Loss: 0.0665, Train Acc: 99.39% - Val Loss: 0.0673, Val Acc: 99.36%
# [Linear probe] Epoch 17/50 - Train Loss: 0.0659, Train Acc: 99.40% - Val Loss: 0.0670, Val Acc: 99.39%
# [Linear probe] Epoch 18/50 - Train Loss: 0.0654, Train Acc: 99.40% - Val Loss: 0.0665, Val Acc: 99.39%
# [Linear probe] Epoch 19/50 - Train Loss: 0.0651, Train Acc: 99.41% - Val Loss: 0.0662, Val Acc: 99.39%
# [Linear probe] Epoch 20/50 - Train Loss: 0.0648, Train Acc: 99.41% - Val Loss: 0.0659, Val Acc: 99.39%
# [Linear probe] Epoch 21/50 - Train Loss: 0.0644, Train Acc: 99.41% - Val Loss: 0.0657, Val Acc: 99.41%
# [Linear probe] Epoch 22/50 - Train Loss: 0.0643, Train Acc: 99.42% - Val Loss: 0.0656, Val Acc: 99.36%
# [Linear probe] Epoch 23/50 - Train Loss: 0.0641, Train Acc: 99.42% - Val Loss: 0.0655, Val Acc: 99.36%
# [Linear probe] Epoch 24/50 - Train Loss: 0.0641, Train Acc: 99.43% - Val Loss: 0.0653, Val Acc: 99.39%
# [Linear probe] Epoch 25/50 - Train Loss: 0.0639, Train Acc: 99.42% - Val Loss: 0.0654, Val Acc: 99.39%
# [Linear probe] Epoch 26/50 - Train Loss: 0.0638, Train Acc: 99.43% - Val Loss: 0.0651, Val Acc: 99.36%
# [Linear probe] Epoch 27/50 - Train Loss: 0.0637, Train Acc: 99.43% - Val Loss: 0.0649, Val Acc: 99.41%
# [Linear probe] Epoch 28/50 - Train Loss: 0.0636, Train Acc: 99.43% - Val Loss: 0.0651, Val Acc: 99.39%
# [Linear probe] Epoch 29/50 - Train Loss: 0.0636, Train Acc: 99.43% - Val Loss: 0.0650, Val Acc: 99.39%
# [Linear probe] Epoch 30/50 - Train Loss: 0.0636, Train Acc: 99.43% - Val Loss: 0.0648, Val Acc: 99.39%
# [Linear probe] Epoch 31/50 - Train Loss: 0.0634, Train Acc: 99.43% - Val Loss: 0.0650, Val Acc: 99.36%
# [Linear probe] Epoch 32/50 - Train Loss: 0.0635, Train Acc: 99.43% - Val Loss: 0.0649, Val Acc: 99.36%
# [Linear probe] Epoch 33/50 - Train Loss: 0.0634, Train Acc: 99.43% - Val Loss: 0.0648, Val Acc: 99.36%
# [Linear probe] Epoch 34/50 - Train Loss: 0.0635, Train Acc: 99.43% - Val Loss: 0.0647, Val Acc: 99.39%
# [Linear probe] Epoch 35/50 - Train Loss: 0.0635, Train Acc: 99.44% - Val Loss: 0.0646, Val Acc: 99.41%
# [Linear probe] Epoch 36/50 - Train Loss: 0.0633, Train Acc: 99.44% - Val Loss: 0.0647, Val Acc: 99.41%
# [Linear probe] Epoch 37/50 - Train Loss: 0.0634, Train Acc: 99.43% - Val Loss: 0.0649, Val Acc: 99.39%
# [Linear probe] Epoch 38/50 - Train Loss: 0.0633, Train Acc: 99.43% - Val Loss: 0.0648, Val Acc: 99.39%
# [Linear probe] Epoch 39/50 - Train Loss: 0.0634, Train Acc: 99.43% - Val Loss: 0.0648, Val Acc: 99.39%
# [Linear probe] Epoch 40/50 - Train Loss: 0.0633, Train Acc: 99.44% - Val Loss: 0.0647, Val Acc: 99.41%
# [Linear probe] Epoch 41/50 - Train Loss: 0.0633, Train Acc: 99.43% - Val Loss: 0.0648, Val Acc: 99.39%
# [Linear probe] Epoch 42/50 - Train Loss: 0.0633, Train Acc: 99.42% - Val Loss: 0.0647, Val Acc: 99.39%
# [Linear probe] Epoch 43/50 - Train Loss: 0.0633, Train Acc: 99.44% - Val Loss: 0.0648, Val Acc: 99.36%
# [Linear probe] Epoch 44/50 - Train Loss: 0.0634, Train Acc: 99.43% - Val Loss: 0.0648, Val Acc: 99.36%
# [Linear probe] Epoch 45/50 - Train Loss: 0.0632, Train Acc: 99.44% - Val Loss: 0.0647, Val Acc: 99.39%
# [Linear probe] Epoch 46/50 - Train Loss: 0.0634, Train Acc: 99.43% - Val Loss: 0.0646, Val Acc: 99.39%
# [Linear probe] Epoch 47/50 - Train Loss: 0.0632, Train Acc: 99.43% - Val Loss: 0.0648, Val Acc: 99.39%
# [Linear probe] Epoch 48/50 - Train Loss: 0.0634, Train Acc: 99.43% - Val Loss: 0.0647, Val Acc: 99.39%
# [Linear probe] Epoch 49/50 - Train Loss: 0.0633, Train Acc: 99.43% - Val Loss: 0.0648, Val Acc: 99.36%
# [Linear probe] Epoch 50/50 - Train Loss: 0.0632, Train Acc: 99.43% - Val Loss: 0.0649, Val Acc: 99.36%
# Linear probe early stopping at epoch 50.
#
# Linear Probe Test Results (SigLIP2 features):
#   Accuracy:  99.34%
#   Precision: 99.34%
#   Recall:    99.34%
#   F1-Score:  99.34%

# %%
# !zip -r results_task3_2.zip /content/TOL506M_Final_Project/results/
# Out:
#   adding: content/TOL506M_Final_Project/results/ (stored 0%)
#   adding: content/TOL506M_Final_Project/results/plots/ (stored 0%)
#   adding: content/TOL506M_Final_Project/results/plots/task3_linear_probe_confusion_matrix.png (deflated 17%)
#   adding: content/TOL506M_Final_Project/results/plots/task3_zero_shot_classification.png (deflated 12%)
#   adding: content/TOL506M_Final_Project/results/task3_zero_shot_and_linear_probe.json (deflated 86%)
#   adding: content/TOL506M_Final_Project/results/metrics/ (stored 0%)
#   adding: content/TOL506M_Final_Project/results/models/ (stored 0%)

# %%
from google.colab import files
files.download("results_task3_2.zip")
